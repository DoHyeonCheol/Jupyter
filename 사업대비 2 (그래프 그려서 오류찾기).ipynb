# %%
import pandas as pd

# %%
data = pd.read_table('./남해대교.txt',sep=',')

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                x        y       z
# 0         393298  3863419 -10.954
# 1         393298  3863418 -10.945
# 2         393298  3863417 -10.943
# 3         393299  3863427 -11.093
# 4         393299  3863426 -11.027
# ...          ...      ...     ...
# 22856957  403711  3864365 -10.340
# 22856958  403711  3864364 -10.310
# 22856959  403711  3864363 -10.350
# 22856960  403711  3864362 -10.340
# 22856961  403711  3864361 -10.340
#
# [22856962 rows x 3 columns]

# %%
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 7.6/7.6 MB 28.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.5/2.5 MB 78.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.0/1.0 MB 66.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 98.3/98.3 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 55.3/55.3 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 163.0/163.0 kB ? eta 0:00:00
# ...

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as pit

# %%
fig = pit.figure()
ax = fig.add_subplot(projection='3d')

# %%
import matplotlib.pyplot as plt
import csv

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []
z = []

with open('Nam.txt', 'r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x.append(int(row[0]))
        y.append(int(row[1]))
        z.append(int(float(row[2])))

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []
z = []

with open('Nam.txt', 'r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x.append(int(row[0]))
        y.append(int(row[1]))
        z.append(int(float(row[2])))

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot(x,y,z, label='int load file')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('Reject')
ax.grid()
ax.legend()

for angle in range(0, 360, 10):
    ax.view_init(elev=30, azim=angle)  # elev: 고도, azim: 방위각
    plt.pause(0.001)

# 그래프 출력
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []
z = []

with open('Nam.txt', 'r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x.append(int(row[0]))
        y.append(int(row[1]))
        z.append(int(float(row[2])))

fig = plt.figure(figsize=(20, 20))   #가로 세로 크기
ax = fig.add_subplot(projection='3d')
ax.plot(x,y,z, label='int load file')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('Reject')
ax.grid()
ax.legend()

ax.view_init(elev=0, azim=0)
plt.show()
